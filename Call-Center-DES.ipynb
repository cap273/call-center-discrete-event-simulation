# %% [markdown]
# ##  Optimizing the Number of Agents in a Call Center Using Discrete Event Simulation
#
# In this Jupyter Notebook, we apply Discrete Event Simulation (DES) to estimate the optimal number of agents required in a call center. The goal is to ensure that a target percentage of incoming calls are answered immediately. Any call that cannot be answered right away is treated as dropped.
#
# The following Python libraries are used:
# - [**simpy**](https://pypi.org/project/simpy/), a framework for discrete-event simulation.
# - [**simpy_helpers**](https://pypi.org/project/simpy-helpers/), a convenience library that simplifies working with `simpy`. Its GitHub repository can be found [here](https://github.com/bambielli/simpy_helpers).
#
# The three main components to `simpy_helpers` are:
# - **Entities**: what flows through the system (e.g. customers, jobs, calls)
# - **Resources**: where Entities go for service
#     - By default, resources can form queues. If queueing is not permitted (as in our call center case), additional logic must be applied to drop entities when capacity is full.
# - **Source**: generates Entities over time to enter the simulation.
#
# A conceptual diagram of `simpy_helpers` components is:
# ![Conceptual Diagram](images/Conceptual.png)
#
# In this DES, we apply `simpy` and `simpy_helpers` to the following model:
# - Incoming calls are represented as Entities.
# - Call center agents are modeled as a Resource.
# - A Source generates calls over the course of the day.
# - Calls not answered immediately (when no agent is available) are routed to a special DroppedCalls Resource to record dropped demand.
#
# ![More Specific Diagram](images/Actual-Sim.png)

# %% [markdown]
# In this model, calls are generated using a Poisson process (see [Poisson distribution](https://en.wikipedia.org/wiki/Poisson_distribution), which is a common way to represent random arrivals over time. Instead of directly sampling the number of calls per interval, we model the time between arrivals (the interarrival time) as an exponential random variable. To reflect daily fluctuations, the average interarrival time changes by hour of the day according to `MEAN_TIME_BETWEEN_CALLS_MINS_BY_HOUR`.
#
# Each incoming call is then classified as either a good call or a bad call based on the specified percentage (`GOOD_CALL_PERCENTAGE`). Good calls have service times drawn from a normal distribution with a mean of `GOOD_CALL_MEAN_DURATION` and a standard deviation of `GOOD_CALL_STDDEV`, while bad calls have much shorter durations drawn uniformly from `BAD_CALL_DURATION_RANGE`.
#
# Finally, the number of available agents (`number_of_agents`) can be varied across simulation runs, allowing us to explore how staffing levels affect the proportion of calls that are answered versus dropped.

# %% [markdown]
# **Credit**: the ideas of this work are taken directly from BUS 36109 Advanced Decision Modeling with Python, taught by Prof. [Don Eisenstein](https://www.chicagobooth.edu/faculty/directory/e/donald-d-eisenstein) at the University of Chicago Booth School of Business.

# %%
### -1. Installing and importing libraries, defining helper functions

# %%
# !pip install numpy -q
# !pip install simpy -q
# !pip install simpy-helpers -q
# !pip install matplotlib -q

# %%
import numpy as np
import simpy
from simpy_helpers import Entity, Resource, Source, Stats
import matplotlib.pyplot as plt

# %%
def get_nonnegative_num_from_normal_dist(mean, st_dev):
    """
    Sample from a normal distribution with the given mean and standard deviation,
    but ensure the returned value is nonnegative.

    Used for modeling call durations that are assumed to be normally distributed, but where negative durations are not possible.

    Reference:
    https://stackoverflow.com/questions/16312006/python-numpy-random-normal-only-positive-values
    """
    x = np.random.normal(mean, st_dev)
    return x if x >= 0 else get_nonnegative_num_from_normal_dist(mean, st_dev)

# %% [markdown]
# ### 0. Defining parameters for the simulation

# %%
# Simulation parameters
SIM_LENGTH_MINS = 540  # Total simulation time: 9 hours (9am–6pm)

# Call arrival parameters (varying by hour of the day)
MEAN_TIME_BETWEEN_CALLS_MINS_BY_HOUR = {
    9: 5,   # From 9–10am, calls every 8 minutes on average
    10: 10, # From 10–11am, calls every 10 minutes on average
    11: 12,
    12: 15,
    13: 9,
    14: 8,
    15: 8,
    16: 8,
    17: 7 # From 5pm-6pm, calls every 7 minutes on average
}

# Call characteristics
GOOD_CALL_PERCENTAGE = 0.60 # 60% of calls are valid leads
BAD_CALL_PERCENTAGE = 1-GOOD_CALL_PERCENTAGE # 40% are wrong numbers / quick asks

# Good call duration (Normal distribution)
GOOD_CALL_MEAN_DURATION = 15 # Average good call duration (minutes)
GOOD_CALL_STDDEV = 5 # Standard deviation of good call duration (minutes)

# Bad call duration (Uniform distribution)
BAD_CALL_DURATION_RANGE = (0, 2)  # Duration uniformly between 0–2 minutes

# Call center parameters
number_of_agents = 2 # Number of agents (will vary in scenarios)

# %% [markdown]
# ### 1. Defining Resource class for the simulation.

# %%
class CallCenter(Resource):
    """
    Resource representing the call center (group of agents) that receives incoming calls.

    Responsibilities:
    - Encapsulates agent availability via the underlying Resource queue.
    - Provides `service_time(entity)` to sample the handling time of a call
      based on its type ("Good" vs "Bad").

    Assumptions:
    - `entity.attributes["call_type"]` is either "Good" or "Bad".
    - Durations are returned in minutes.
    - Uses:
        - Good calls: Normal(mean=GOOD_CALL_MEAN_DURATION, sd=GOOD_CALL_STDDEV)
        - Bad calls:  Uniform(low=BAD_CALL_DURATION_RANGE[0],
                              high=BAD_CALL_DURATION_RANGE[1])
    """

    def service_time(self, entity):
        call_type = entity.attributes["call_type"]

        if call_type == "Good":
            return float(get_nonnegative_num_from_normal_dist(GOOD_CALL_MEAN_DURATION, GOOD_CALL_STDDEV))
        elif call_type == "Bad":
            low, high = BAD_CALL_DURATION_RANGE
            return float(np.random.uniform(low, high))
        else:
            raise ValueError(f"Unknown call_type: {call_type!r}")

# %% [markdown]
# ### 1b. Defining a *Renege* resource for dropped calls
# - Dropped calls are routed to a special DroppedCalls resource.
# - This resource has effectively infinite capacity (so no queue forms).
# - Each dropped call spends exactly 1 time unit there.
# - The total processing time at this resource therefore equals the total number of dropped calls.
# - This provides an elegant alternative to counting drops via an entity attribute.

# %%
class DroppedCalls(Resource):
    """
    Resource to account for dropped/reneged calls.

    Idea:
    - Give this resource very large capacity so no queue ever forms.
    - Each dropped call "uses" this resource for a deterministic time of 1
      time unit (minute), so the total processing time here equals the count
      of dropped calls.

    Usage:
    - Instantiate with a large capacity, e.g.:
        dropped_calls = DroppedCalls(env, capacity=10**9)
    """
    def service_time(self, entity):
        # Deterministic 1-minute service time = 1 'unit' per dropped call.
        return 1

# %% [markdown]
# ### 2. Defining Entity class for the simulation

# %%
class Call(Entity):
    """
    A single incoming phone call passing through the system.

    Lifecycle:
    1) Arrives at the call center.
    2) If an agent is free *right now*, the call is answered immediately and
       processed at `call_center` (no waiting allowed).
    3) Otherwise, the call is dropped (reneges) and is routed to the
       `DroppedCalls` resource for a deterministic 1-minute 'accounting' stay.

    Attributes set upstream (in Source):
    - call_id (int/str): Unique identifier for the call.
    - call_type (str): Either "Good" or "Bad".
    """

    def process(self):
        # No-wait policy:
        # - If a slot is free now, proceed with normal processing.
        # - If not, mark as dropped and send to DroppedCalls for 1 time unit.
        if call_center.count < call_center.capacity:
            self.attributes["outcome"] = "answered"

            # (Optional) debug print:
            print(f"CALL ANSWERED (type: {self.attributes["call_type"]}): {call_center.count} of {call_center.capacity} agents busy")

            # Reserve an agent (simpy_helpers bookkeeping)
            yield self.wait_for_resource(call_center)

            # Be processed by the call center (duration determined by call type)
            yield self.process_at_resource(call_center)

            # Release the agent
            self.release_resource(call_center)

        else:
            self.attributes["outcome"] = "dropped"

            # (Optional) debug print:
            print(f"*** CALL DROPPED (type: {self.attributes["call_type"]}): {call_center.count} of {call_center.capacity} agents busy")

            # Enter DroppedCalls to 'account' for the drop (1 time unit)
            # Capacity is effectively infinite, so this should never block.
            yield self.wait_for_resource(dropped_calls)
            yield self.process_at_resource(dropped_calls)
            self.release_resource(dropped_calls)

# %% [markdown]
# ### 3. Defining Source class for the simulation

# %%
class CallSource(Source):
    """
    Source that generates incoming phone calls.

    Responsibilities:
    - Determines interarrival times between calls, which vary by hour of day
      using the dictionary `MEAN_TIME_BETWEEN_CALLS_MINS_BY_HOUR`.
    - Creates new `Call` entities and assigns their attributes.

    Methods:
    - interarrival_time(): Returns the time until the next call, based on
      current simulation hour (drawn from an exponential distribution).
    - build_entity(): Constructs a `Call` object with a `call_type`
      ("Good" or "Bad") assigned probabilistically.

    Notes:
    - `call_type` is sampled using `GOOD_CALL_PERCENTAGE`.
    - A unique `call_id` is also assigned for tracking/logging.
    """

    def interarrival_time(self):
        # Determine current hour from simulation time
        current_hour = int(self.env.now // 60) + 9  # env.now in minutes, starting at 9am
        try:
            mean_time = MEAN_TIME_BETWEEN_CALLS_MINS_BY_HOUR[current_hour]
        except KeyError:
            raise KeyError(
                f"No mean interarrival time defined for hour {current_hour}. "
                "Please update MEAN_TIME_BETWEEN_CALLS_MINS_BY_HOUR to cover all hours "
                "in the simulation."
            )
        # Exponential distribution for interarrival times
        return np.random.exponential(mean_time)

    def build_entity(self):
        # Determine call type based on GOOD_CALL_PERCENTAGE
        if np.random.rand() < GOOD_CALL_PERCENTAGE:
            call_type = "Good"
        else:
            call_type = "Bad"

        attributes = {
            "call_type": call_type,
        }

        # Create call entity
        call = Call(self.env, attributes)
        
        return call

# %% [markdown]
# ### 4. Run your simulation

# %%
# Reproducibility: fix the RNG seed so results are consistent across runs.
# Comment out this line if you want a randomized run each time instead.
np.random.seed(422)

# Create the SimPy environment (time unit: minutes)
env = simpy.Environment()

# Instantiate the call-center resource with the chosen number of agents (capacity)
call_center = CallCenter(env, capacity=number_of_agents)

# Instantiate the "renege" resource for dropped calls
# Capacity is set very large so it never blocks
dropped_calls = DroppedCalls(env, capacity=10**9)

# Instantiate the source that generates calls
call_source = CallSource(env)

# Start the source’s generator process.
# Set debug=True if you want it to print its own debug output
env.process(call_source.start(debug=True))

# Advance the simulation until the configured end time (in minutes)
env.run(until=SIM_LENGTH_MINS)
# Out:
# Debug is Enabled
# Call 1 created_at: 1.420162081113496 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 1 requesting CallCenter: 1.420162081113496
# Call 1 started processing at CallCenter : 1.420162081113496
# Call 2 created_at: 2.3878626930828846 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 2 requesting CallCenter: 2.3878626930828846
# Call 2 started processing at CallCenter : 2.3878626930828846
# Call 2 finished at CallCenter: 3.9400936127415247
# Call 2 disposed: 3.9400936127415247
# Call 3 created_at: 12.88751548836839 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 3 requesting CallCenter: 12.88751548836839
# Call 3 started processing at CallCenter : 12.88751548836839
# Call 3 finished at CallCenter: 12.979940644752395
# Call 3 disposed: 12.979940644752395
# Call 1 finished at CallCenter: 16.747460861614172
# Call 1 disposed: 16.747460861614172
# Call 4 created_at: 18.325625136286604 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 4 requesting CallCenter: 18.325625136286604
# Call 4 started processing at CallCenter : 18.325625136286604
# Call 4 finished at CallCenter: 19.250882133562257
# Call 4 disposed: 19.250882133562257
# Call 5 created_at: 24.102488536237363 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 5 requesting CallCenter: 24.102488536237363
# Call 5 started processing at CallCenter : 24.102488536237363
# Call 6 created_at: 27.382561444596583 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 6 requesting CallCenter: 27.382561444596583
# Call 6 started processing at CallCenter : 27.382561444596583
# Call 7 created_at: 27.5605646097002 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 7 requesting DroppedCalls: 27.5605646097002
# Call 7 started processing at DroppedCalls : 27.5605646097002
# Call 6 finished at CallCenter: 27.73513404585398
# Call 6 disposed: 27.73513404585398
# Call 8 created_at: 28.4245500876375 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 8 requesting CallCenter: 28.4245500876375
# Call 8 started processing at CallCenter : 28.4245500876375
# Call 7 finished at DroppedCalls: 28.5605646097002
# Call 7 disposed: 28.5605646097002
# Call 8 finished at CallCenter: 28.575573656264336
# Call 8 disposed: 28.575573656264336
# Call 9 created_at: 30.229112546396852 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 9 requesting CallCenter: 30.229112546396852
# Call 9 started processing at CallCenter : 30.229112546396852
# Call 9 finished at CallCenter: 31.28705360222482
# Call 9 disposed: 31.28705360222482
# Call 5 finished at CallCenter: 41.62253314392475
# Call 5 disposed: 41.62253314392475
# Call 10 created_at: 47.6777910896496 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 10 requesting CallCenter: 47.6777910896496
# Call 10 started processing at CallCenter : 47.6777910896496
# Call 11 created_at: 50.62450017154232 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 11 requesting CallCenter: 50.62450017154232
# Call 11 started processing at CallCenter : 50.62450017154232
# Call 12 created_at: 58.10751117886704 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 12 requesting DroppedCalls: 58.10751117886704
# Call 12 started processing at DroppedCalls : 58.10751117886704
# Call 11 finished at CallCenter: 58.5197261989696
# Call 11 disposed: 58.5197261989696
# Call 12 finished at DroppedCalls: 59.10751117886704
# Call 12 disposed: 59.10751117886704
# Call 13 created_at: 64.34621531207146 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 13 requesting CallCenter: 64.34621531207146
# Call 13 started processing at CallCenter : 64.34621531207146
# Call 10 finished at CallCenter: 68.11057336286105
# Call 10 disposed: 68.11057336286105
# Call 13 finished at CallCenter: 82.70023076210164
# Call 13 disposed: 82.70023076210164
# Call 14 created_at: 88.92234936816003 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 14 requesting CallCenter: 88.92234936816003
# Call 14 started processing at CallCenter : 88.92234936816003
# Call 14 finished at CallCenter: 90.24529630751157
# Call 14 disposed: 90.24529630751157
# Call 15 created_at: 104.71533081596195 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 15 requesting CallCenter: 104.71533081596195
# Call 15 started processing at CallCenter : 104.71533081596195
# Call 16 created_at: 104.98065518673992 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 16 requesting CallCenter: 104.98065518673992
# Call 16 started processing at CallCenter : 104.98065518673992
# Call 17 created_at: 105.32071840105607 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 17 requesting DroppedCalls: 105.32071840105607
# Call 17 started processing at DroppedCalls : 105.32071840105607
# Call 16 finished at CallCenter: 106.05200477241459
# Call 16 disposed: 106.05200477241459
# Call 17 finished at DroppedCalls: 106.32071840105607
# Call 17 disposed: 106.32071840105607
# Call 15 finished at CallCenter: 108.98883469675008
# Call 15 disposed: 108.98883469675008
# Call 18 created_at: 118.98538506008249 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 18 requesting CallCenter: 118.98538506008249
# Call 18 started processing at CallCenter : 118.98538506008249
# Call 19 created_at: 121.32274481676487 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 19 requesting CallCenter: 121.32274481676487
# Call 19 started processing at CallCenter : 121.32274481676487
# Call 20 created_at: 131.29864038787375 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Bad): 2 of 2 agents busy
# Call 20 requesting DroppedCalls: 131.29864038787375
# Call 20 started processing at DroppedCalls : 131.29864038787375
# Call 20 finished at DroppedCalls: 132.29864038787375
# Call 20 disposed: 132.29864038787375
# Call 18 finished at CallCenter: 134.66648120466104
# Call 18 disposed: 134.66648120466104
# Call 21 created_at: 135.94003321935847 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 21 requesting CallCenter: 135.94003321935847
# Call 21 started processing at CallCenter : 135.94003321935847
# Call 19 finished at CallCenter: 142.1009147597928
# Call 19 disposed: 142.1009147597928
# Call 21 finished at CallCenter: 145.89768432855655
# Call 21 disposed: 145.89768432855655
# Call 22 created_at: 150.1791114716366 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 22 requesting CallCenter: 150.1791114716366
# Call 22 started processing at CallCenter : 150.1791114716366
# Call 22 finished at CallCenter: 150.36249421967707
# Call 22 disposed: 150.36249421967707
# Call 23 created_at: 174.58125449596528 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 23 requesting CallCenter: 174.58125449596528
# Call 23 started processing at CallCenter : 174.58125449596528
# Call 24 created_at: 178.31673443949495 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 24 requesting CallCenter: 178.31673443949495
# Call 24 started processing at CallCenter : 178.31673443949495
# Call 25 created_at: 181.82700544124629 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 25 requesting DroppedCalls: 181.82700544124629
# Call 25 started processing at DroppedCalls : 181.82700544124629
# Call 25 finished at DroppedCalls: 182.82700544124629
# Call 25 disposed: 182.82700544124629
# Call 23 finished at CallCenter: 191.39489550313368
# Call 23 disposed: 191.39489550313368
# Call 24 finished at CallCenter: 199.602580475371
# Call 24 disposed: 199.602580475371
# Call 26 created_at: 212.85714126955673 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 26 requesting CallCenter: 212.85714126955673
# Call 26 started processing at CallCenter : 212.85714126955673
# Call 27 created_at: 223.8381662980716 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 27 requesting CallCenter: 223.8381662980716
# Call 27 started processing at CallCenter : 223.8381662980716
# Call 26 finished at CallCenter: 226.54618557462402
# Call 26 disposed: 226.54618557462402
# Call 27 finished at CallCenter: 232.13243381854966
# Call 27 disposed: 232.13243381854966
# Call 28 created_at: 233.92154321735958 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 28 requesting CallCenter: 233.92154321735958
# Call 28 started processing at CallCenter : 233.92154321735958
# Call 28 finished at CallCenter: 234.25421395073252
# Call 28 disposed: 234.25421395073252
# Call 29 created_at: 261.2981216319626 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 29 requesting CallCenter: 261.2981216319626
# Call 29 started processing at CallCenter : 261.2981216319626
# Call 29 finished at CallCenter: 262.9495397394332
# Call 29 disposed: 262.9495397394332
# Call 30 created_at: 266.09049958784306 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 30 requesting CallCenter: 266.09049958784306
# Call 30 started processing at CallCenter : 266.09049958784306
# Call 30 finished at CallCenter: 267.6750277351446
# Call 30 disposed: 267.6750277351446
# Call 31 created_at: 283.70308282621784 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 31 requesting CallCenter: 283.70308282621784
# Call 31 started processing at CallCenter : 283.70308282621784
# Call 31 finished at CallCenter: 292.7418560889867
# Call 31 disposed: 292.7418560889867
# Call 32 created_at: 297.7036648291214 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 32 requesting CallCenter: 297.7036648291214
# Call 32 started processing at CallCenter : 297.7036648291214
# Call 32 finished at CallCenter: 305.54890796719155
# Call 32 disposed: 305.54890796719155
# Call 33 created_at: 309.0915534622092 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 33 requesting CallCenter: 309.0915534622092
# Call 33 started processing at CallCenter : 309.0915534622092
# Call 34 created_at: 316.0445652727193 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 34 requesting CallCenter: 316.0445652727193
# Call 34 started processing at CallCenter : 316.0445652727193
# Call 34 finished at CallCenter: 317.9020430060527
# Call 34 disposed: 317.9020430060527
# Call 35 created_at: 321.42800974362615 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 35 requesting CallCenter: 321.42800974362615
# Call 35 started processing at CallCenter : 321.42800974362615
# Call 36 created_at: 326.2805044094872 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Bad): 2 of 2 agents busy
# Call 36 requesting DroppedCalls: 326.2805044094872
# Call 36 started processing at DroppedCalls : 326.2805044094872
# Call 36 finished at DroppedCalls: 327.2805044094872
# Call 36 disposed: 327.2805044094872
# Call 33 finished at CallCenter: 327.973067049414
# Call 33 disposed: 327.973067049414
# Call 37 created_at: 332.301520291703 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 37 requesting CallCenter: 332.301520291703
# Call 37 started processing at CallCenter : 332.301520291703
# Call 38 created_at: 337.9058943448985 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Bad): 2 of 2 agents busy
# Call 38 requesting DroppedCalls: 337.9058943448985
# Call 38 started processing at DroppedCalls : 337.9058943448985
# Call 35 finished at CallCenter: 337.9594372215359
# Call 35 disposed: 337.9594372215359
# Call 38 finished at DroppedCalls: 338.9058943448985
# Call 38 disposed: 338.9058943448985
# Call 39 created_at: 339.6777233500393 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 39 requesting CallCenter: 339.6777233500393
# Call 39 started processing at CallCenter : 339.6777233500393
# Call 37 finished at CallCenter: 340.4187415035257
# Call 37 disposed: 340.4187415035257
# Call 40 created_at: 343.74821661493866 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 40 requesting CallCenter: 343.74821661493866
# Call 40 started processing at CallCenter : 343.74821661493866
# Call 39 finished at CallCenter: 346.7580014331769
# Call 39 disposed: 346.7580014331769
# Call 40 finished at CallCenter: 352.7592903780107
# Call 40 disposed: 352.7592903780107
# Call 41 created_at: 356.4548124813327 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 41 requesting CallCenter: 356.4548124813327
# Call 41 started processing at CallCenter : 356.4548124813327
# Call 42 created_at: 363.4833342088576 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 42 requesting CallCenter: 363.4833342088576
# Call 42 started processing at CallCenter : 363.4833342088576
# Call 43 created_at: 365.82831432445295 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 43 requesting DroppedCalls: 365.82831432445295
# Call 43 started processing at DroppedCalls : 365.82831432445295
# Call 43 finished at DroppedCalls: 366.82831432445295
# Call 43 disposed: 366.82831432445295
# Call 44 created_at: 369.63349996146246 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 44 requesting DroppedCalls: 369.63349996146246
# Call 44 started processing at DroppedCalls : 369.63349996146246
# Call 44 finished at DroppedCalls: 370.63349996146246
# Call 44 disposed: 370.63349996146246
# Call 41 finished at CallCenter: 372.0808987342785
# Call 41 disposed: 372.0808987342785
# Call 42 finished at CallCenter: 376.28867837271224
# Call 42 disposed: 376.28867837271224
# Call 45 created_at: 377.39433376287536 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 45 requesting CallCenter: 377.39433376287536
# Call 45 started processing at CallCenter : 377.39433376287536
# Call 45 finished at CallCenter: 378.1369787652885
# Call 45 disposed: 378.1369787652885
# Call 46 created_at: 398.85850853407385 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 46 requesting CallCenter: 398.85850853407385
# Call 46 started processing at CallCenter : 398.85850853407385
# Call 47 created_at: 402.2532805198297 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 47 requesting CallCenter: 402.2532805198297
# Call 47 started processing at CallCenter : 402.2532805198297
# Call 48 created_at: 412.9619643909411 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Bad): 2 of 2 agents busy
# Call 48 requesting DroppedCalls: 412.9619643909411
# Call 48 started processing at DroppedCalls : 412.9619643909411
# Call 48 finished at DroppedCalls: 413.9619643909411
# Call 48 disposed: 413.9619643909411
# Call 46 finished at CallCenter: 415.25333992347043
# Call 46 disposed: 415.25333992347043
# Call 47 finished at CallCenter: 416.68292530861913
# Call 47 disposed: 416.68292530861913
# Call 49 created_at: 423.1643024045563 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 49 requesting CallCenter: 423.1643024045563
# Call 49 started processing at CallCenter : 423.1643024045563
# Call 50 created_at: 430.14868557034055 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 50 requesting CallCenter: 430.14868557034055
# Call 50 started processing at CallCenter : 430.14868557034055
# Call 51 created_at: 436.2543203674463 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 51 requesting DroppedCalls: 436.2543203674463
# Call 51 started processing at DroppedCalls : 436.2543203674463
# Call 51 finished at DroppedCalls: 437.2543203674463
# Call 51 disposed: 437.2543203674463
# Call 49 finished at CallCenter: 439.90229000244386
# Call 49 disposed: 439.90229000244386
# Call 50 finished at CallCenter: 450.4072432082449
# Call 50 disposed: 450.4072432082449
# Call 52 created_at: 468.28937731206753 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 52 requesting CallCenter: 468.28937731206753
# Call 52 started processing at CallCenter : 468.28937731206753
# Call 53 created_at: 475.10336282045176 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 53 requesting CallCenter: 475.10336282045176
# Call 53 started processing at CallCenter : 475.10336282045176
# Call 54 created_at: 476.9294702713797 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# *** CALL DROPPED (type: Good): 2 of 2 agents busy
# Call 54 requesting DroppedCalls: 476.9294702713797
# Call 54 started processing at DroppedCalls : 476.9294702713797
# Call 54 finished at DroppedCalls: 477.9294702713797
# Call 54 disposed: 477.9294702713797
# Call 52 finished at CallCenter: 481.3595383041496
# Call 52 disposed: 481.3595383041496
# Call 55 created_at: 486.8171493103893 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 55 requesting CallCenter: 486.8171493103893
# Call 55 started processing at CallCenter : 486.8171493103893
# Call 55 finished at CallCenter: 488.0734658018989
# Call 55 disposed: 488.0734658018989
# Call 53 finished at CallCenter: 493.1797680307527
# Call 53 disposed: 493.1797680307527
# Call 56 created_at: 503.34112998672856 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 0 of 2 agents busy
# Call 56 requesting CallCenter: 503.34112998672856
# Call 56 started processing at CallCenter : 503.34112998672856
# Call 56 finished at CallCenter: 503.6039223080541
# Call 56 disposed: 503.6039223080541
# Call 57 created_at: 514.1361871054926 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 0 of 2 agents busy
# Call 57 requesting CallCenter: 514.1361871054926
# Call 57 started processing at CallCenter : 514.1361871054926
# Call 58 created_at: 523.5236694991111 attributes: {'call_type': 'Good', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Good): 1 of 2 agents busy
# Call 58 requesting CallCenter: 523.5236694991111
# Call 58 started processing at CallCenter : 523.5236694991111
# Call 57 finished at CallCenter: 524.765003770716
# Call 57 disposed: 524.765003770716
# Call 59 created_at: 537.8943403930523 attributes: {'call_type': 'Bad', 'priority': 1, 'disposed': False, 'type': <class '__main__.Call'>}
# CALL ANSWERED (type: Bad): 1 of 2 agents busy
# Call 59 requesting CallCenter: 537.8943403930523
# Call 59 started processing at CallCenter : 537.8943403930523
# Call 59 finished at CallCenter: 538.169076668859
# Call 59 disposed: 538.169076668859
